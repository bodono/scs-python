# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
log_csv_filename = '~/git/solver_benchmarks/csv/LISWET1'

# %%
df = pd.read_csv(log_csv_filename)

# %%
print(df.columns)
# Out:
# Index(['iter', 'res_pri', 'res_dual', 'gap', 'pri_resid_nrm_inf',
#        'dual_resid_nrm_inf', 'pri_resid_nrm_2', 'dual_resid_nrm_2',
#        'res_infeas', 'res_unbdd_a', 'res_unbdd_p', 'pobj', 'dobj', 'tau',
#        'kap', 'scale', 'diff_u_ut_nrm_2', 'diff_v_v_prev_nrm_2',
#        'diff_u_ut_nrm_inf', 'diff_v_v_prev_nrm_inf', 'aa_norm', 'time',
#        'Unnamed: 22'],
#       dtype='object')

# %%
plt.semilogy(df.iter, np.minimum(df.diff_u_ut_nrm_2, 1e5))
plt.semilogy(df.iter, np.minimum(df.diff_v_v_prev_nrm_2, 1e5))
plt.plot(df.scale)

# %%
plt.semilogy(df.iter, np.minimum(df.diff_u_ut_nrm_inf, 1e5))
plt.semilogy(df.iter, np.minimum(df.diff_v_v_prev_nrm_inf, 1e5))
plt.plot(df.scale)

# %%
plt.semilogy(df.iter, np.minimum(df.pri_resid_nrm_2, 1e5))
plt.semilogy(df.iter, np.minimum(df.dual_resid_nrm_2, 1e5))
plt.plot(df.scale)

# %%
plt.semilogy(df.iter, np.minimum(df.pri_resid_nrm_2 / df.tau, 1e5))
plt.semilogy(df.iter, np.minimum(df.dual_resid_nrm_2 / df.tau, 1e5))
plt.semilogy(df.iter, np.minimum(df.gap, 1e5))
plt.plot(df.scale)

# %%
plt.semilogy(df.iter, np.minimum(df.pri_resid_nrm_inf / df.tau, 1e5))
plt.semilogy(df.iter, np.minimum(df.dual_resid_nrm_inf / df.tau, 1e5))
plt.plot(df.scale)

# %%
plt.semilogy(df.iter, np.minimum(df.res_pri, 10000.))
plt.semilogy(df.iter, np.minimum(df.res_dual, 10000.))
plt.semilogy(df.iter, np.minimum(df.gap, 10000.))
plt.plot(df.scale)

# %%
plt.plot(df.aa_norm)

# %%
plt.plot(df.time, df.scale)

# %%
plt.plot(df.pobj[100:])
plt.plot(df.dobj[100:])
