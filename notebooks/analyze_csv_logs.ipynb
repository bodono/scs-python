# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
log_csv_filename = '~/git/solver_benchmarks/csv/CONT-201'

# %%
df = pd.read_csv(log_csv_filename)

# %%
print(df.columns)
# Out:
# Index(['iter', 'res_pri', 'res_dual', 'gap', 'res_infeas', 'res_unbdd_a',
#        'res_unbdd_p', 'pobj', 'dobj', 'tau', 'kap', 'scale', 'nrm_diff_u_ut',
#        'nrm_diff_v_v_prev', 'aa_norm', 'time', 'Unnamed: 16'],
#       dtype='object')

# %%
plt.semilogy(df.iter, np.minimum(df.res_pri, 10000.))
plt.semilogy(df.iter, np.minimum(df.res_dual, 10000.))
plt.semilogy(df.iter, np.minimum(df.gap, 10000.))
plt.plot(df.scale)

# %%
plt.plot(df.aa_norm)

# %%
plt.plot(df.time, df.scale)

# %%
plt.plot(df.pobj[100:])
plt.plot(df.dobj[100:])
